# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Series

# %%
s1=pd.Series([34,67,90,34,12,67])
s1
# Out:
# 0    34
# 1    67
# 2    90
# 3    34
# 4    12
# 5    67
# dtype: int64

# %%
print(s1[0])
# Out:
# 34

# %%
print(s1[0:3])
# Out:
# 0    34
# 1    67
# 2    90
# dtype: int64

# %%
print(s1[0::2])
# Out:
# 0    34
# 2    90
# 4    12
# dtype: int64

# %% [markdown]
# Data frame :

# %%
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame({
    "Name" : ["vansh","abhay","dhruvi"],
    "Age" : [20,18,22],
    "Marks" : [80,98,94]
})

# %%
df
# Out:
#      Name  Age  Marks
# 0   vansh   20     80
# 1   abhay   18     98
# 2  dhruvi   22     94

# %%
df["Name"]
# Out:
# 0     vansh
# 1     abhay
# 2    dhruvi
# Name: Name, dtype: object

# %%
df[["Name","Marks"]]
# Out:
#      Name  Marks
# 0   vansh     80
# 1   abhay     98
# 2  dhruvi     94

# %%
df["Marks"]
# Out:
# 0    80
# 1    98
# 2    94
# Name: Marks, dtype: int64

# %%
df["Name"][0]
# Out:
# 'vansh'

# %%
df
# Out:
#      Name  Age  Marks
# 0   vansh   20     80
# 1   abhay   18     98
# 2  dhruvi   22     94

# %%
df["city"]=["delhi","mumbai","pune"]
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     80   delhi
# 1   abhay   18     98  mumbai
# 2  dhruvi   22     94    pune

# %%
df["city"]=["surat","baroda","amreli"]
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     80   surat
# 1   abhay   18     98  baroda
# 2  dhruvi   22     94  amreli

# %%
print(df)
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     80   surat
# 1   abhay   18     98  baroda
# 2  dhruvi   22     94  amreli

# %%
df["Age"].dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Name     object
# Age       int64
# Marks     int64
# city     object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
df["Marks"]
# Out:
# 0    80
# 1    98
# 2    94
# Name: Marks, dtype: int64

# %%
df["Marks"]+2
# Out:
# 0     82
# 1    100
# 2     96
# Name: Marks, dtype: int64

# %%
df["Marks"]-2
# Out:
# 0    78
# 1    96
# 2    92
# Name: Marks, dtype: int64

# %%
df["Marks"]*2
# Out:
# 0    160
# 1    196
# 2    188
# Name: Marks, dtype: int64

# %%
df["Marks"]/2
# Out:
# 0    40.0
# 1    49.0
# 2    47.0
# Name: Marks, dtype: float64

# %%
df["Marks"]%2
# Out:
# 0    0
# 1    0
# 2    0
# Name: Marks, dtype: int64

# %%
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     80   surat
# 1   abhay   18     98  baroda
# 2  dhruvi   22     94  amreli

# %%
df["Marks"]=df["Marks"]+2
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     82   surat
# 1   abhay   18    100  baroda
# 2  dhruvi   22     96  amreli

# %%
df["Marks"]=df["Marks"]-2
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20     80   surat
# 1   abhay   18     98  baroda
# 2  dhruvi   22     94  amreli

# %%
df["Marks"]=df["Marks"]*2
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20    160   surat
# 1   abhay   18    196  baroda
# 2  dhruvi   22    188  amreli

# %%
df["Marks"]=df["Marks"]/2
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20   80.0   surat
# 1   abhay   18   98.0  baroda
# 2  dhruvi   22   94.0  amreli

# %%
df["Marks"]=df["Marks"]%2
df
# Out:
#      Name  Age  Marks    city
# 0   vansh   20    0.0   surat
# 1   abhay   18    0.0  baroda
# 2  dhruvi   22    0.0  amreli

# %%
type(df["Marks"])
# Out:
# pandas.core.series.Series

# %%
df2=pd.DataFrame([
    ["aaryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86]
])
df2
# Out:
#         0      1       2
# 0  aaryan  vansh  dhruvi
# 1      20     22      18
# 2      98     78      86

# %%
df3=pd.DataFrame([
    ["aaryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86]
], index=["Name","Age","Marks"])
df3
# Out:
#             0      1       2
# Name   aaryan  vansh  dhruvi
# Age        20     22      18
# Marks      98     78      86

# %%
df3=pd.DataFrame([
    ["aaryan","vansh","dhruvi"],
    [20,22,18],
    [98,78,86]
], columns=["Name","Age","Marks"])
df3
# Out:
#      Name    Age   Marks
# 0  aaryan  vansh  dhruvi
# 1      20     22      18
# 2      98     78      86

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df3["Name"])
# Out:
# pandas.core.series.Series

# %%
# iloc & loc

# %%
dd=[["alice",25,"us"],
["bob",34,"america"],
["champ",22,"pune"]]

# %%
df2=pd.DataFrame(dd,columns=["Name","Age","city"])
df2
# Out:
#     Name  Age     city
# 0  alice   25       us
# 1    bob   34  america
# 2  champ   22     pune

# %%
df2["Name"]
# Out:
# 0    alice
# 1      bob
# 2    champ
# Name: Name, dtype: object

# %%
df2.Name
# Out:
# 0    alice
# 1      bob
# 2    champ
# Name: Name, dtype: object

# %%
df2.Name[0]
# Out:
# 'alice'

# %%
df2
# Out:
#     Name  Age     city
# 0  alice   25       us
# 1    bob   34  america
# 2  champ   22     pune

# %%
df2.iloc[0]
# Out:
# Name    alice
# Age        25
# city       us
# Name: 0, dtype: object

# %%
df2.iloc[0:2]
# Out:
#     Name  Age     city
# 0  alice   25       us
# 1    bob   34  america

# %%
df2.iloc[0::2]
# Out:
#     Name  Age  city
# 0  alice   25    us
# 2  champ   22  pune

# %%
df2.iloc[0:2,0:2]
# Out:
#     Name  Age
# 0  alice   25
# 1    bob   34

# %%
df2
# Out:
#     Name  Age     city
# 0  alice   25       us
# 1    bob   34  america
# 2  champ   22     pune

# %%
df2.loc[0]
# Out:
# Name    alice
# Age        25
# city       us
# Name: 0, dtype: object

# %%
# how to set index from existing column.

# %%
df3=df2.set_index("Name")

# %%
df3
# Out:
#        Age     city
# Name
# alice   25       us
# bob     34  america
# champ   22     pune

# %%
df3.loc["bob"]
# Out:
# Age          34
# city    america
# Name: bob, dtype: object

# %%
df3.loc[["alice","champ"]]
# Out:
#        Age  city
# Name
# alice   25    us
# champ   22  pune

# %%
df3.loc["alice":"bob"]
# Out:
#        Age     city
# Name
# alice   25       us
# bob     34  america

# %%
df3.loc[df3["city"]!="us"]
# Out:
#        Age     city
# Name
# bob     34  america
# champ   22     pune
