# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# 1.Load Dataset

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")
df

# %%
df.head()

# %%
df.tail()

# %%
df.sample()

# %% [markdown]
# 2.Data Cleaning

# %% [markdown]
# ->Cheack for missing value

# %%
df.isna()

# %%
df.isnull().sum()

# %% [markdown]
# ->Fill missing value

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df = df.drop(columns=['Cabin'])

# %%
print(df.isnull().sum())

# %%
df.duplicated().sum()

# %%
df.dtypes

# %% [markdown]
# ->Summarize Data

# %%
df.info()

# %%
df.describe()

# %%
df["Pclass"].describe()

# %% [markdown]
# ->Sorting

# %%
df

# %%
df.sort_values(by="Ticket",ascending=True)

# %%
df.sort_values(by="Ticket",ascending=True)

# %% [markdown]
# ->Filtering

# %%
df

# %%
df[df["Age"]>30]

# %% [markdown]
# ->Aggregation

# %%
print(df["Age"].min())

# %%
print(df["Age"].max())

# %%
(df["Age"].sum())

# %%
(df["Age"].mean())

# %%
(df["Age"].count())

# %% [markdown]
# ->Visualization

# %% [markdown]
# ->1.Bar plot

# %%
import numpy as np
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

plt.figure(figsize=(8,5))
sns.barplot(x="pclass", y="fare", data=df, estimator=np.sum, errorbar=None)

plt.xlabel("Passenger Class")
plt.ylabel("Total Fare")
plt.title("Total Fare by Class")
plt.show()

# %% [markdown]
# ->2.Line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

line_data = df.groupby("pclass")['fare'].sum().reset_index()

plt.figure(figsize=(10,5))
sns.lineplot(data=line_data, x='pclass', y='fare')

plt.title("Total Fare per Class")
plt.show()

# %% [markdown]
# ->3.Scatter plot

# %%
df = sns.load_dataset("titanic")

line_data = df.groupby("pclass")['fare'].sum().reset_index()

plt.figure(figsize=(10,5))
plt.scatter(line_data['pclass'], line_data['fare'])

plt.title("Total Fare per Class")
plt.xlabel("Passenger Class")
plt.ylabel("Total Fare")

plt.show()

# %% [markdown]
# ->4.Pie plot

# %%
df = sns.load_dataset("titanic")

pie_data = df.groupby("pclass")['fare'].sum().reset_index()

plt.figure(figsize=(7,7))
plt.pie(pie_data['fare'], labels=pie_data['pclass'], autopct="%0.1f%%")

plt.title("Total Fare Contribution per Class")
plt.show()

# %% [markdown]
# ->5.Histogram plot

# %%
df = sns.load_dataset("titanic")

plt.figure(figsize=(10,5))
plt.hist(df['fare'], bins=20, color='skyblue', edgecolor='black')

plt.title("Fare Distribution of Passengers")
plt.xlabel("Fare")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# ->6.Heatmap plot

# %%
df = sns.load_dataset("titanic")
heat_data = df.pivot_table(values='fare', index='pclass', columns='sex', aggfunc='sum')
plt.figure(figsize=(8,5))
sns.heatmap(heat_data, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Total Fare by Class and Gender")
plt.xlabel("Gender")
plt.ylabel("Passenger Class")

plt.show()
