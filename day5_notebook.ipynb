# %%
import os
os.listdir()

# %%
import pandas as pd

# %%
df=pd.read_excel("filtered_transactions.xlsx")
df

# %%
df.to_csv("filtered_transactions.csv",index=False)
df

# %%
df.head()

# %%
df.head(10)

# %%
df.tail()

# %%
df.tail(8)

# %%
df.sample()

# %%
df.sample(5)

# %%
#missing value:
df.isna()

# %%
df.isna().sum()

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
# 1.categorical \ qualitative data
#2.numerical \ quantitative data

# %%
# 1=>a.nominal 
#    b.ordinal

# %%
#2=>1.descript
#   2.countinue

# %%
df

# %%
df.dtypes

# %%
# df['payment_method']

# %%
df["transaction_date"]

# %%
from datetime import datetime

# %%
ans = datetime.strptime(str(df['transaction_date'][1046])[:10], "%Y-%m-%d") \
          .strftime("%d-%m-%Y")

# %%
# ans=datetime.strptime(df["transaction_date"])[1046]("%Y-%m-%d").strftime("%d-%m-%Y")

# %%
ans

# %%
# all_dates=[]

# %%
all_dates = []  # make sure the list is initialized

for date in df["transaction_date"]:
    formatted_date = date.strftime("%d/%m/%Y")  # directly use strftime on Timestamp
    all_dates.append(formatted_date)

print(all_dates)

# %%
# for date in df ["transaction_date"]:all_dates.append(datetime.strptime(date,"%Y-%m-%d").strftime("%d/%m/%Y"))

# %%
# date_series=pd.series(all_dates)

# %%
date_series = pd.Series(all_dates)  # Capital 'S' in Series

print(date_series)

# %%
(date_series)

# %%
df["transaction_date"]=date_series

# %%
df["transaction_date"]

# %%
df

# %%
df["transaction_date"].head(10)

# %%
# df["transaction_date"]=pd.to_datetime(df["transaction_date"])

# %%
df["transaction_date"] = pd.to_datetime(df["transaction_date"], dayfirst=True)

print(df["transaction_date"])

# %%
df["transaction_date"]

# %%
df

# %%
df.isnull().sum()

# %%
#missing value :

# %%
df.dropna(inplace=True)

# %%
df

# %%
df.isna().sum()

# %%
df=pd.read_csv("filtered_transactions.csv")

# %%
df.isna().sum()

# %%
df["category"]=df["category"].fillna("-")

# %%
df.isna().sum()

# %%
df

# %%
df["amount"].fillna(df["amount"].mean(),inplace=True)

# %%
df.isna().sum()

# %%
df.duplicated()

# %%
print(df.duplicated().sum())

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

# %%
df.dtypes

# %%
ndf = df["amount"].astype(int)

# %%
ndf.dtypes

# %%
ndf

# %%
df

# %%
ndf=df["amount"].astype("int32")

# %%
ndf.dtypes

# %%
ndf

# %%
df
